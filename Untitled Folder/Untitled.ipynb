# %%
# !ls
# Out:
# Untitled.ipynb

# %%
import numpy as np

data1 = np.load("/uscms_data/d3/mkim/MKWorkingArea/CMSSW_10_2_0/src/JL/Melrose/P2_CMSSW_10_1_5/src/L1TMuonSimulations/Analyzers/test7/histos_tba.20.npz")

X_org = data1["variables"]

y_org = data1["parameters"]

# %%
X_org[:10]
# Out:
# array([[ 3.1900000e+03,            nan,  3.5460000e+03,  3.5680000e+03,
#                    nan,            nan,            nan,  3.5680000e+03,
#                    nan,  3.1270000e+03,  3.5240000e+03,  3.0740000e+03,
#          2.0000000e+01,            nan,  1.7000000e+01,  1.6000000e+01,
#                    nan,            nan,            nan,  2.0000000e+01,
#                    nan,  2.2000000e+01,  1.9000000e+01,  2.2000000e+01,
#          2.2151711e+01,            nan,  1.0000000e+00,  0.0000000e+00,
#                    nan,            nan,            nan,  0.0000000e+00,
#                    nan,  3.0000000e+00,  1.0000000e+00,  1.7000000e+01,
#          0.0000000e+00,            nan,  0.0000000e+00,  0.0000000e+00,
#                    nan,            nan,            nan,  0.0000000e+00,
#                    nan,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          4.0000000e+00,            nan,  1.0000000e+00,  1.0000000e+00,
# ...

# %%
X_org.shape
# Out:
# (3272341, 87)

# %%
X = np.zeros((X_org.shape[0],4))
for i in range(X_org.shape[0]):
  ind = np.zeros(X_org.shape[0])
  if ~(np.isnan(X_org[i,2]) or np.isnan(X_org[i,3]) or np.isnan(X_org[i,4]) or (np.isnan(X_org[i,0]) and np.isnan(X_org[i,1]))):
    if ~np.isnan(X_org[i,0]):
      X[i,0] = X_org[i,0].copy()
    elif ~np.isnan(X_org[i,1]):
      X[i,0] = X_org[i,1].copy()
    X[i,1] = X_org[i,2].copy()
    X[i,2] = X_org[i,3].copy()
    X[i,3] = X_org[i,4].copy()
    ind[i] = 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-3ac579660fe0> in <module>()
#       1 X = np.zeros((X_org.shape[0],4))
#       2 for i in range(X_org.shape[0]):
# ----> 3   ind = np.zeros(X_org.shape[0])
#       4   if ~(np.isnan(X_org[i,2]) or np.isnan(X_org[i,3]) or np.isnan(X_org[i,4]) or (np.isnan(X_org[i,0]) and np.isnan(X_org[i,1]))):
#       5     if ~np.isnan(X_org[i,0]):
#
# KeyboardInterrupt:

# %%
X[:100]

# %%
X.shape[0]
# Out:
# 3272341

# %%
X != 0
# Out:
# array([[False, False, False, False],
#        [False, False, False, False],
#        [ True,  True,  True,  True],
#        ...,
#        [False, False, False, False],
#        [ True,  True,  True,  True],
#        [False, False, False, False]])
