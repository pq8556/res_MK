# %%
import numpy as np

# %%
dir1 = '/uscms_data/d3/mkim/MKWorkingArea/CMSSW_10_2_0/src/JL/Melrose/P2_CMSSW_10_1_5/src/L1TMuonSimulations/Analyzers/'
infile_muon = dir1 + 'test7/histos_tba.20.npz'
infile_pileup = dir1 + 'test7/histos_tbd.20.npz'
infile_muon_omtf = dir1 + 'test7/histos_tba_omtf.22.npz'
infile_pileup_omtf = dir1 + 'test7/histos_tbd_omtf.22.npz'

# %%
loaded = np.load(infile_muon)

# %%
the_variables_0 = loaded['variables']

# %%
the_parameters_0 = loaded['parameters']

# %%
a = np.where((the_parameters_0[:,0] < 0.05) & (the_parameters_0[:,0] > 0.025))
aa = a[0]

# %%
print(aa[:100])
# Out:
# [  26   52   88  112  172  188  236  256  270  298  344  362  387  413
#   423  504  508  604  619  631  656  685  720  722  748  798  817  884
#   890  925 1164 1197 1236 1251 1317 1384 1396 1418 1446 1493 1518 1554
#  1560 1578 1636 1655 1659 1693 1704 1805 1838 1853 1903 1907 1929 1995
#  2127 2151 2167 2175 2193 2221 2224 2282 2326 2327 2396 2401 2452 2453
#  2462 2481 2508 2550 2555 2596 2648 2665 2702 2721 2752 2757 2825 2826
#  2865 2907 2938 2960 2982 3001 3015 3112 3115 3144 3149 3196 3265 3268
#  3310 3333]

# %% [markdown]
# phi for CSC 4987.0 ~ 5000 is max, 94~100 is min
# theta for CSC 88~90 is max, 5~10 is min
#
# So divide phi by 5000 -> [0,1]
# divide theta by 90 -> [0,1]

# %%
print(np.nanmax(the_variables_0[:,12+0]))
print(np.nanmax(the_variables_0[:,12+1]))
print(np.nanmax(the_variables_0[:,12+2]))
print(np.nanmax(the_variables_0[:,12+3]))
print(np.nanmax(the_variables_0[:,12+4]))
# Out:
# 53.0
# 88.0
# 88.0
# 88.0
# 88.0

# %%
for e in aa[:100]:
    print(the_variables_0[e,0:5])
    print(the_variables_0[e,12+0:12+5])
    print(the_parameters_0[e,0],1/the_parameters_0[e,0])
    print("")
# Out:
# [3749.   nan 3720. 3720. 3720.]
# [35. nan 33. 33. 34.]
# (0.034915175, 28.640841460058933)
#
# [2243.   nan 2232. 2232.   nan]
# [38. nan 38. 38. nan]
# (0.028010668, 35.700683456760835)
#
# [1716.   nan 1712. 1712. 1712.]
# [ 9. nan  8.  8.  8.]
# (0.041317303, 24.20293518302044)
#
# [  nan 4072. 4064. 4064. 4064.]
# [nan 70. 71. 71. 71.]
# (0.029016575, 34.463061383071356)
#
# [  nan 2769. 2748. 2744. 2745.]
# [nan 64. 64. 64. 64.]
# (0.04432254, 22.561884310643507)
#
# [4256.   nan   nan 4216. 4218.]
# [ 9. nan nan  8.  8.]
# (0.04972071, 20.112344223908035)
#
# [4489.   nan 4464. 4458. 4464.]
# [16. nan 16. 16. 16.]
# (0.035814043, 27.922008030365646)
#
# [2436.   nan 2408. 2400. 2392.]
# [18. nan 17. 17. 17.]
# (0.04969981, 20.120801508650914)
#
# [1579.   nan 1544. 1538. 1536.]
# [20. nan 19. 19. 19.]
# (0.047116436, 21.224016150892627)
#
# [2321.   nan 2286. 2280.   nan]
# [38. nan 37. 37. nan]
# (0.047275536, 21.15258947096355)
#
# [4269.   nan 4286. 4250. 4240.]
# [ 9. nan  9.  9.  9.]
# (0.032391727, 30.87208042057769)
#
# [  nan 2048. 2036. 2033. 2032.]
# [nan 74. 74. 74. 74.]
# (0.025273904, 39.56650274187358)
#
# [4388.   nan 4344. 4336.   nan]
# [34. nan 33. 33. nan]
# (0.040169578, 24.894461148301033)
#
# [1983.   nan 1960.   nan 1962.]
# [ 9. nan  9. nan  9.]
# (0.046051856, 21.714651352363393)
#
# [3473. 3452.   nan 3432. 3431.]
# [53. 52. nan 51. 51.]
# (0.03671493, 27.23687605073629)
#
# [  nan   nan 3400. 3392. 3392.]
# [nan nan  6.  6.  6.]
# (0.045921244, 21.77641367774029)
#
# [  nan   nan 4556. 4544.   nan]
# [nan nan 61. 61. nan]
# (0.049311064, 20.279424436561058)
#
# [3883.   nan 3872. 3864. 3864.]
# [12. nan 11. 12. 12.]
# (0.035887673, 27.86472073978328)
#
# [2789.   nan 2760. 2752. 2752.]
# [30. nan 29. 29. 30.]
# (0.039500587, 25.316079679663744)
#
# [4727.   nan 4698. 4688. 4688.]
# [33. nan 31. 31. 32.]
# (0.042908963, 23.30515431678339)
#
# [2851.   nan 2832. 2832. 2832.]
# [28. nan 28. 27. 28.]
# (0.03238002, 30.883243738886982)
#
# [3573.   nan 3616. 3608. 3608.]
# [18. nan 18. 18. 18.]
# (0.041970756, 23.826113646024268)
#
# [  nan 3845. 3820. 3816.   nan]
# [nan 82. 82. 82. nan]
# (0.04698617, 21.282858287730022)
#
# [4379.   nan 4344.   nan 4332.]
# [44. nan 43. nan 42.]
# (0.037248183, 26.84694710819861)
#
# [  nan 2448. 2431. 2428. 2424.]
# [nan 64. 64. 64. 64.]
# (0.026691785, 37.46471046876831)
#
# [2831.   nan 2798.   nan 2796.]
# [44. nan 44. nan 44.]
# (0.029269416, 34.165355534317456)
#
# [1511. 1498.   nan 1472. 1468.]
# [48. 47. nan 47. 47.]
# (0.029333351, 34.09088834975222)
#
# [3840.   nan 3824. 3816. 3816.]
# [20. nan 19. 19. 19.]
# (0.032968912, 30.331604261004912)
#
# [4740.   nan 4712. 4712. 4712.]
# [24. nan 23. 23. 23.]
# (0.044162232, 22.64378282081829)
#
# [  nan 4773. 4756. 4748. 4748.]
# [nan 61. 60. 60. 60.]
# (0.044850368, 22.296361064964128)
#
# [  nan 1700. 1692. 1692. 1692.]
# [nan 54. 54. 54. 55.]
# (0.028186621, 35.47782456352279)
#
# [1724.   nan 1688. 1680. 1682.]
# [28. nan 28. 28. 28.]
# (0.03488593, 28.66484997097053)
#
# [  nan 4848. 4828. 4824. 4824.]
# [nan 75. 75. 74. 74.]
# (0.049316626, 20.277137352132986)
#
# [2955.   nan 2968. 2968. 2968.]
# [ 5. nan  6.  6.  6.]
# (0.04037528, 24.76762940415054)
#
# [2405.   nan 2416. 2408. 2408.]
# [47. nan 45. 46. 46.]
# (0.039460868, 25.3415613928692)
#
# [3998. 3980.   nan 3968. 3968.]
# [48. 48. nan 48. 48.]
# (0.037464567, 26.691887632847685)
#
# [4550.   nan 4512. 4504. 4504.]
# [39. nan 38. 38. 39.]
# (0.04363368, 22.91807571306227)
#
# [  nan 1848. 1836. 1836. 1832.]
# [nan 53. 53. 53. 54.]
# (0.032811258, 30.477344098150425)
#
# [4757.   nan 4712. 4712. 4723.]
# [34. nan 33. 33. 33.]
# (0.04608844, 21.697415511489826)
#
# [4648.   nan 4632. 4632. 4624.]
# [ 7. nan  6.  6.  7.]
# (0.02618369, 38.19171272471126)
#
# [2284.   nan   nan 2256. 2240.]
# [27. nan nan 25. 26.]
# (0.0365493, 27.360305155533595)
#
# [2686. 2665.   nan 2644. 2648.]
# [48. 47. nan 47. 47.]
# (0.04207611, 23.766455122393474)
#
# [2211.   nan 2184. 2176. 2176.]
# [ 9. nan  8.  8.  8.]
# (0.042012755, 23.80229537673108)
#
# [1578.   nan 1538.   nan 1516.]
# [41. nan 40. nan 41.]
# (0.042822383, 23.35227331843648)
#
# [4430.   nan 4400. 4400.   nan]
# [25. nan 24. 24. nan]
# (0.034947574, 28.61428939338897)
#
# [2368.   nan 2352. 2344. 2344.]
# [18. nan 17. 17. 17.]
# (0.045636605, 21.912234480877203)
#
# [  nan 1731. 1708. 1700. 1696.]
# [nan 62. 62. 63. 62.]
# (0.048447195, 20.641029700625417)
#
# [2249.   nan 2232.   nan 2224.]
# [ 9. nan  8. nan  8.]
# (0.04406855, 22.69192035105952)
#
# [3709.   nan 3688. 3680. 3688.]
# [ 7. nan  8.  8.  8.]
# (0.045585476, 21.936811694731563)
#
# [  nan 3564.   nan 3540. 3536.]
# [nan 55. nan 55. 54.]
# (0.038697727, 25.84131102494628)
#
# [4749.   nan 4720. 4712. 4712.]
# [10. nan  9.  9.  9.]
# (0.04433683, 22.554612384560468)
#
# [  nan 3675. 3672. 3671. 3668.]
# [nan 58. 57. 58. 57.]
# (0.026494859, 37.74317153601519)
#
# [2623.   nan 2600. 2592. 2592.]
# [15. nan 14. 14. 14.]
# (0.046293225, 21.60143297403028)
#
# [1708.   nan 1670. 1664. 1656.]
# [27. nan 26. 26. 26.]
# (0.049940623, 20.023778901036668)
#
# [  nan 4036. 4024. 4028. 4024.]
# [nan 62. 62. 63. 62.]
# (0.030648889, 32.627610069150094)
#
# [  nan 1496. 1481. 1476. 1476.]
# [nan 55. 55. 55. 55.]
# (0.034896556, 28.65612273448773)
#
# [1289.   nan 1280. 1280. 1280.]
# [ 7. nan  7.  7.  7.]
# (0.02508928, 39.85765924346524)
#
# [  nan 4845. 4832.   nan 4828.]
# [nan 69. 68. nan 68.]
# (0.026948301, 37.10809061721307)
#
# [  nan 4281.   nan 4244. 4240.]
# [nan 53. nan 53. 54.]
# (0.04520799, 22.119984405987527)
#
# [4891.   nan 4832. 4830. 4832.]
# [19. nan 18. 18. 19.]
# (0.039265066, 25.467930964078644)
#
# [4861. 4836.   nan 4753. 4812.]
# [52. 52. nan 52. 52.]
# (0.04793935, 20.859690871306256)
#
# [3281.   nan 3240.   nan 3235.]
# [44. nan 43. nan 42.]
# (0.041737366, 23.959345896285623)
#
# [2401.   nan 2384. 2382. 2384.]
# [30. nan 28. 28. 28.]
# (0.027202811, 36.76090668030274)
#
# [3274.   nan 3232. 3216. 3216.]
# [26. nan 25. 25. 25.]
# (0.04711724, 21.223653689636997)
#
# [3376.   nan 3352. 3352.   nan]
# [28. nan 28. 28. nan]
# (0.026306057, 38.01405838734764)
#
# [2242. 2228.   nan 2212. 2209.]
# [52. 53. nan 52. 52.]
# (0.026652832, 37.51946568379769)
#
# [2943.   nan 2926. 2928. 2936.]
# [16. nan 16. 16. 16.]
# (0.03921766, 25.498717728292146)
#
# [  nan 1868. 1852.   nan 1845.]
# [nan 60. 60. nan 60.]
# (0.04149106, 24.101576702923197)
#
# [4801.   nan   nan 4768.   nan]
# [24. nan nan 24. nan]
# (0.0321631, 31.09153185024849)
#
# [2525.   nan 2480. 2478. 2470.]
# [19. nan 19. 19. 19.]
# (0.046779867, 21.376717347375546)
#
# [  nan 1698. 1687. 1688.   nan]
# [nan 82. 82. 82. nan]
# (0.033793937, 29.591106467503522)
#
# [4462.   nan 4440. 4432. 4430.]
# [14. nan 14. 14. 14.]
# (0.028359575, 35.26145906805528)
#
# [3962.   nan 3934. 3936. 3936.]
# [24. nan 23. 23. 23.]
# (0.028600728, 34.96414479834742)
#
# [  nan 2488. 2476. 2471. 2468.]
# [nan 73. 73. 73. 74.]
# (0.028622054, 34.93809407414175)
#
# [  nan 1364. 1352. 1348. 1347.]
# [nan 77. 77. 77. 77.]
# (0.040641125, 24.60561790121086)
#
# [2981.   nan 2958.   nan 2957.]
# [43. nan 43. nan 43.]
# (0.029503265, 33.894553249813995)
#
# [  nan 1668. 1660. 1660. 1660.]
# [nan 53. 53. 53. 53.]
# (0.025290433, 39.54064319297719)
#
# [2671.   nan 2648. 2648.   nan]
# [25. nan 25. 25. nan]
# (0.039504647, 25.31347751434115)
#
# [2849.   nan 2816. 2816. 2814.]
# [28. nan 27. 27. 27.]
# (0.04082591, 24.49424835310712)
#
# [1877. 1848. 1832. 1825. 1813.]
# [47. 47. 47. 47. 47.]
# (0.043866586, 22.796394535124954)
#
# [4272.   nan 4224.   nan 4215.]
# [42. nan 41. nan 41.]
# (0.0454493, 22.002538318211727)
#
# [  nan 3240. 3227. 3224. 3220.]
# [nan 81. 81. 81. 81.]
# (0.035475016, 28.188852970233814)
#
# [  nan   nan   nan 3266.   nan]
# [nan nan nan  5. nan]
# (0.03451287, 28.97469841258191)
#
# [  nan 2300.   nan 2284. 2283.]
# [nan 71. nan 70. 71.]
# (0.041971453, 23.82571818750352)
#
# [1874.   nan 1840. 1832.   nan]
# [25. nan 24. 24. nan]
# (0.03866408, 25.86379902898309)
#
# [  nan   nan 3304. 3296. 3293.]
# [nan nan 79. 79. 79.]
# (0.04813331, 20.77563336995935)
#
# [3271.   nan 3248. 3240. 3232.]
# [18. nan 17. 17. 18.]
# (0.04311448, 23.194064002495367)
#
# [2231.   nan 2208. 2200. 2200.]
# [15. nan 14. 14. 14.]
# (0.03153991, 31.705861384314286)
#
# [  nan   nan 2856. 2816. 2824.]
# [nan nan 32. 32. 32.]
# (0.027661376, 36.151491913990206)
#
# [  nan 4252. 4244. 4244. 4244.]
# [nan 81. 81. 81. 81.]
# (0.04115488, 24.298454961783417)
#
# [2381.   nan 2344. 2344. 2344.]
# [40. nan 40. 40. 41.]
# (0.033712342, 29.66272674512917)
#
# [2784.   nan 2760. 2760.   nan]
# [ 8. nan  7.  7. nan]
# (0.049580567, 20.16919266713762)
#
# [2161.   nan 2152. 2154. 2152.]
# [32. nan 31. 31. 31.]
# (0.029207757, 34.237480433868306)
#
# [  nan 2804. 2828. 2792. 2788.]
# [nan 59. 59. 59. 60.]
# (0.027569525, 36.27193439268344)
#
# [3444.   nan 3416. 3416. 3408.]
# [14. nan 13. 14. 14.]
# (0.04434578, 22.55005939190086)
#
# [  nan 3304. 3296. 3287. 3284.]
# [nan 87. 87. 87. 87.]
# (0.029008845, 34.4722447437252)
#
# [1208.   nan 1168. 1164. 1160.]
# [46. nan 45. 45. 45.]
# (0.038647313, 25.87502030255702)
#
# [1863.   nan 1854. 1848. 1848.]
# [15. nan 14. 14. 14.]
# (0.038487524, 25.982445775099947)
#
# [  nan 3905. 3892. 3874. 3885.]
# [nan 65. 65. 65. 64.]
# (0.044539917, 22.45177049057748)
#
# [2096.   nan 2112. 2072.   nan]
# [36. nan 35. 35. nan]
# (0.030385187, 32.91077337887269)

# %%
print(the_parameters_0[:10,0])

# %%
loaded2 = np.load(infile_pileup)

# %%
type(loaded2)

# %%
print(loaded2.keys())

# %%
aux2 = loaded2['aux']

# %%
print(aux2[20000:20010])
